# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_acc = np.load('test_accuracy.npy')
train_acc = np.load('train_accuracy.npy')

# %%
x = np.arange(len(test_losses))
y_1 = test_acc
y_2 = train_acc
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.legend(['test', 'train'])
plt.title('Custom LeNet, EMNIST(ByMerge) [SGD lr=0.005]')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
test_acc_1 = np.load('test_accuracy.npy')
train_acc_1 = np.load('train_accuracy.npy')

# %%
x = np.arange(len(test_losses))
y_1 = test_acc_1
y_2 = train_acc_1
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.legend(['test', 'train'])
plt.title('Custom LeNet, EMNIST(ByMerge) [SGD lr=0.005]')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
test_loss = np.load('test_losses.npy')
train_loss = np.load('train_losses.npy')

# %%
x = np.arange(len(test_losses))
y_1 = test_loss
y_2 = train_loss
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.legend(['test', 'train'])
plt.title('Custom LeNet, EMNIST(ByMerge) [SGD lr=0.005]')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
